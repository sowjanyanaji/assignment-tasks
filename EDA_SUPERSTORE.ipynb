# %% [markdown]
# #                               Title : EDA on Superstore

# %%
#importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing the data set

# %%
df1 = pd.read_excel(r"C:\Users\anaji\Sowjanya\Task FOLDER\Pandas\Sample_-_Superstore.xls",sheet_name = 0)
df2 = pd.read_excel(r"C:\Users\anaji\Sowjanya\Task FOLDER\Pandas\Sample_-_Superstore.xls",sheet_name = 1)
df3 = pd.read_excel(r"C:\Users\anaji\Sowjanya\Task FOLDER\Pandas\Sample_-_Superstore.xls",sheet_name = 2)

# %%
df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # columns of the data set

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Returned', 'Order ID'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Person', 'Region'], dtype='object')

# %% [markdown]
# # Description of data set

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Returned  296 non-null    object
#  1   Order ID  296 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Person  4 non-null      object
#  1   Region  4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df1.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df2.describe()
# Out:
#        Returned        Order ID
# count       296             296
# unique        1             296
# top         Yes  CA-2017-153822
# freq        296               1

# %%
df3.describe()
# Out:
#                Person Region
# count               4      4
# unique              4      4
# top     Anna Andreadi   West
# freq                1      1

# %% [markdown]
# # Data cleaning

# %% [markdown]
# 1.Duplicates
# 2.Structural Errors
# 3.Missing values
# 4.Type Casting
# 5.Outliers
#
# if needed we have to work on
# dummy variable
# variance
# transformation

# %%
#finding the duplicates

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Returned, Order ID]
# Index: []

# %%
df3[df3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Person, Region]
# Index: []

# %% [markdown]
# **Conclusion** : no duplicate values present in the three sheets

# %%
#structural errors

# %%
for i in df1.columns:
    print(i,df1[i].unique())
    print()
# Out:
# Row ID [   1    2    3 ... 9992 9993 9994]
#
# Order ID ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914']
#
# Order Date ['2016-11-08T00:00:00.000000000' '2016-06-12T00:00:00.000000000'
#  '2015-10-11T00:00:00.000000000' ... '2016-06-03T00:00:00.000000000'
#  '2015-04-12T00:00:00.000000000' '2014-01-21T00:00:00.000000000']
#
# Ship Date ['2016-11-11T00:00:00.000000000' '2016-06-16T00:00:00.000000000'
#  '2015-10-18T00:00:00.000000000' ... '2015-05-23T00:00:00.000000000'
#  '2014-01-23T00:00:00.000000000' '2017-03-03T00:00:00.000000000']
#
# Ship Mode ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
# Customer ID ['CG-12520' 'DV-13045' 'SO-20335' 'BH-11710' 'AA-10480' 'IM-15070'
#  'HP-14815' 'PK-19075' 'AG-10270' 'ZD-21925' 'KB-16585' 'SF-20065'
#  'EB-13870' 'EH-13945' 'TB-21520' 'MA-17560' 'GH-14485' 'SN-20710'
#  'LC-16930' 'RA-19885' 'ES-14080' 'ON-18715' 'PO-18865' 'LH-16900'
# ...

# %% [markdown]
# **Conclusion**:There are no structural errors in the data set

# %%
#Missing values

# %%
df1.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df1.drop('Row ID',axis = 1, inplace = True)
df1
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df2.isna().sum()
# Out:
# Returned    0
# Order ID    0
# dtype: int64

# %%
df3.isna().sum()
# Out:
# Person    0
# Region    0
# dtype: int64

# %% [markdown]
# **Conclusion** : There are no missing values in the data set

# %%
#outliers

# %% [markdown]
# we can check outliers through statiscal method for other than objet data type,box plot through visualisation

# %%
df=  df1.select_dtypes(exclude="object")
for i in df.columns:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)

    IQR = Q3-Q1
    lower = Q1 - (1.5*IQR)
    upper = Q3 + (1.5*IQR)
    df[(df[i]<lower)] = lower
    df[(df[i]>upper)]= upper
    print(f"  {i} Lower_limit {lower} ")
    print(f"  {i} Upper_limit {upper} ")
    print()
# Out:
#   Order Date Lower_limit 2012-06-04 00:00:00
#   Order Date Upper_limit 2020-05-01 00:00:00
#
#   Ship Date Lower_limit 2012-06-08 00:00:00
#   Ship Date Upper_limit 2020-05-05 00:00:00
#
#   Postal Code Lower_limit -76954.5
#   Postal Code Upper_limit 190185.5
#
#   Sales Lower_limit -271.71000000000004
#   Sales Upper_limit 498.93
#
#   Quantity Lower_limit -4.0
#   Quantity Upper_limit 12.0
#
#   Discount Lower_limit -0.30000000000000004
#   Discount Upper_limit 0.5
#
#   Profit Lower_limit -26.0146
#   Profit Upper_limit 44.691

# %%
df['Sales'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# **Conclusion** :
#
#     1. max value,min value : 110,-50
#     2.Q1: 1
#     3.Q3: 50
#     4.MEDIAN:20
#     5.OUTLIERS :500(above 110)
#     6.Not normally distributed,as whisker length on the lowerside is shorter than the upper.
#     7. IQR = 1 TO 50

# %%
df['Quantity'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# **conclusion** :
#
# 1. max value,min value : 11,-1
# 2. Q1: 0
# 3. Q3: 5
# 4. MEDIAN:2.5
# 5. OUTLIERS :above11(2),below 0 (1 at -30)
# 6. Not normally distributed,as whisker length on the lowerside is shorter than the upper.
# 7. IQR = 0 TO 5

# %%
df['Profit'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# **conclusion** :
#
# 1. max value,min value : 47,-26
# 2. Q1: 0
# 3. Q3: 18
# 4. MEDIAN:5
# 5. OUTLIERS :No outliers
# 6. Not normally distributed,as whisker length on the lowerside is shorter than the upper.
# 7. IQR = 0 TO 18

# %% [markdown]
# **overall conclusion for box plot** : for sales, profits,quantity
#
# The dataset is Positively Skewed (Right-Skewed):In a positively skewed distribution, the right tail (the larger values) is longer or fatter than the left tail. This means that the majority of the data points are concentrated on the left side of the distribution, with a few larger values on the right side. The mean is typically greater than the median in a positively skewed distribution

# %%
df[['Profit','Sales']].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
#  In financial data, a positively skewed distribution might indicate more losses and fewer gains.

# %% [markdown]
# # Data visualisation

# %% [markdown]
# ### Univariate analysis(single column)
# 1. it can be number or categorical
# 2. if the data contains numerical/numbers--> we need to use HBD plot(h-histogram,b-boxplot,d-density plot)
# 3. if the data contains categorical variates--> we use CBP plot(c-countplot,barplot,piechart)

# %%
#histogram

# %%
df1['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['Discount'].plot(kind = 'hist', figsize = (5,3),color='#fc03a1')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['Profit'].plot(kind = 'hist', figsize = (5,3),color='#fc036b')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['Quantity'].plot(kind = 'hist', figsize = (5,3),color='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#box plot already done at checking outliers

# %%
#kde

# %%
df1['Sales'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df1['Quantity'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df1['Profit'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df1['Discount'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#categorical

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sns.countplot(data = df1,x = 'Category' , color = 'pink', orient = 'h')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data = df1,x = 'Segment' , color = 'pink', orient = 'h')
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
#Bar plot

# %%
df1['State'].value_counts().plot(kind = 'barh', figsize = (9,7), color = ['pink', 'violet'])
# Out:
# <Axes: >

# %%
df1['Region'].value_counts().plot(kind = 'barh', figsize = (9,7), color = ['pink', 'violet'])
# Out:
# <Axes: >

# %%
df1['Sub-Category'].value_counts().plot(kind = 'bar', color = ['skyblue', 'blue'], figsize = (15,7))
# Out:
# <Axes: >

# %%
#pie chart

# %%
df1['Ship Mode'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', figsize = (5,5))
# Out:
# <Axes: ylabel='Ship Mode'>

# %% [markdown]
# **Conclusion**
#
# 1. Most of the people prefered standard class ship mode
# 2. Binders and papers are the high-demand products
# 3. From California , west region purchased highest products out of other regions.

# %% [markdown]
# ## Bi variate analysis
#
# 1. Categorical & Categorical: Cross tab, Count plot, Stacked/Group Bar chart
#
# 2. Categorical & Numerical : Bar chart, Group By, Pivot, Line chart
#
# 3. Numerical & Numerical : Correlation, Scatter plot

# %% [markdown]
# ## Categorical & Categorical:

# %%
#crosstab

# %%
pd.crosstab(df1['Sub-Category'],df1['Category'])
# Out:
# Category      Furniture  Office Supplies  Technology
# Sub-Category
# Accessories           0                0         775
# Appliances            0              466           0
# Art                   0              796           0
# Binders               0             1523           0
# Bookcases           228                0           0
# Chairs              617                0           0
# Copiers               0                0          68
# Envelopes             0              254           0
# Fasteners             0              217           0
# Furnishings         957                0           0
# Labels                0              364           0
# Machines              0                0         115
# Paper                 0             1370           0
# Phones                0                0         889
# Storage               0              846           0
# Supplies              0              190           0
# ...

# %% [markdown]
# **Conclusion** :
#
# 1. Phones are the most saled products in the category of Technology
# 2. Binders are the most saled products in the category  of Office Supplies
# 3. Furnishings	are the most saled products in the category  of Furniture

# %%
pd.crosstab(index=df1['Ship Mode'], columns=[df1['Category'], df1['Region']], values=df1['Sales'], aggfunc='mean')
# Out:
# Category         Furniture                                      \
# Region             Central        East       South        West
# Ship Mode
# First Class     328.716022  306.360875  389.677385  347.989822
# Same Day        315.795929  367.216314  225.072615  337.859953
# Second Class    331.777909  346.739661  401.646396  389.609032
# Standard Class  348.237047  355.661959  335.996037  351.000684
#
# Category       Office Supplies                                      \
# Region                 Central        East       South        West
# Ship Mode
# First Class         111.436805  120.406257  120.172421   97.730614
# Same Day             78.631324  102.525798   82.486327   88.807910
# Second Class        126.595030  139.822320  151.474559  142.088627
# Standard Class      119.059181  115.433300  123.028326  115.572314
#
# Category        Technology
# Region             Central        East       South        West
# Ship Mode
# ...

# %%
# above crosstab is for avg sales in each region in respective of product category as well as shipmode

# %%
pd.crosstab(index=df1['Region'],columns=df1['Category'],values=df1['Sales'],aggfunc='mean')
# Out:
# Category   Furniture  Office Supplies  Technology
# Region
# Central   340.534644       117.458801  405.753124
# East      346.574383       120.044425  495.278469
# South     353.309289       126.282727  507.753952
# West      357.302325       116.422377  420.687533

# %% [markdown]
# **Conclusion** :
# 1. Least sales from Office supplies(binders-ref from 1st crosstab) from West Region
# 2. Highest sales from Technology(phones) from South Region

# %%
#Count plot

# %%
sns.countplot(data = df1,x  = 'Category',hue = 'Sub-Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
#bar plot

# %%
import matplotlib.pyplot as plt

a = df1['Country']
b = df1[df1['Region'] == 'South'].groupby('Country').size()
c = df1[df1['Segment'] == 'Consumer'].groupby('Country').size()

fig, ax = plt.subplots()
ax.bar(a, b, label='South')
ax.bar(a, c, bottom=b, label='Consumer')

ax.set_ylabel('Count')
ax.legend()
plt.show()
# Out:
# C:\Users\anaji\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Categorical & Numerical

# %% [markdown]
# #Bar chart.
# #Group by.
# #pivot
# #line chart

# %%
#groupby

# %%
df1.groupby(by ='Product Name' )['Sales'].min()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    7.420
# #10 Gummed Flap White Envelopes, 100/Box                                                                6.608
# #10 Self-Seal White Envelopes                                                                           8.872
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             12.536
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                13.984
#                                                                                                         ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    33.520
# iOttie HLCRIO102 Car Mount                                                                             15.992
# ...

# %%
#grouping the data based on Sub-Category from different areas

# %%
df1.groupby(by='Segment')['Sales'].count()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Sales, dtype: int64

# %%
#pivot table can only be used for one dimension array

# %%
df1.pivot_table(index='Segment',values='Profit',columns='Discount',aggfunc='mean')
# Out:
# Discount          0.00       0.10       0.15       0.20       0.30  \
# Segment
# Consumer     64.161707  93.630090  15.744638  22.426571 -48.018291
# Corporate    71.584290  99.802956  49.282143  23.157672 -46.241380
# Home Office  66.961384  97.234865  30.271889  34.734830 -37.189678
#
# Discount           0.32        0.40        0.45        0.50       0.60  \
# Segment
# Consumer    -102.708631  -93.462041 -216.651900 -253.572181 -38.639822
# Corporate    -82.702010 -132.003562 -280.968633 -388.164788 -40.623326
# Home Office  -57.226350 -119.900858 -175.146900 -377.121333 -60.039948
#
# Discount           0.70        0.80
# Segment
# Consumer    -106.962433 -115.213404
# Corporate    -68.023771  -96.815833
# Home Office -115.479956  -62.509202

# %%
#bar chart

# %%
sns.countplot(data = df1,x  = 'Segment',hue = 'Discount')
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
# line chart

# %%
df1['Profit'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df1['Sales'].head()
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# Name: Sales, dtype: float64

# %% [markdown]
# # Numerical & Numerical :
#
# Correlation, Scatter plot

# %%
df1.plot('Sales','Profit',kind = 'scatter')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# **Conclusion** :
#
# direction always gives positive or negative, directly proportional so positive: as sales increases--profit increases
#
# strength : pearson co reltn co efficient val

# %%
df1.corr(numeric_only=True)
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# strength --0.479064

# %%
sns.heatmap(df1.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df1)

# %% [markdown]
# **Conclusion** :
# 1. Discount and profit are negatively corelated, the value is around(-0.02-0):weak
# 2. Most of the columns i.e (profit and quantity,profit-discount) are around(0-0.2) : no or weak relationship
# 3. The correlation between profit and sales is moderate
