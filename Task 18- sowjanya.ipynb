# %% [markdown]
# In this assignment, you will create a Python program to calculate the average grade of students in a function. However, the program should handle various exceptions that might occur during user input and grade calculation.
#
# Requirements:
#
# Your program should prompt the user to enter the total number of students.
#
# For each student, prompt the user to enter their name and three subject marks (out of 100).
#
# Handle the following exceptions:
#
# 1. ValueError: If the user enters a non-numeric value for the number of students or subject marks.
#
# 2. ZeroDivisionError: If any student's average marks cannot be calculated due to division by zero (e.g., no subject marks provided).
#
# 3. NegativeValueError: If any student's marks are negative.
#
# 4. Display appropriate error messages for each exception and prompt the user to try again.
#
# 5. Use a try-except block for exception handling.
#
# 6. Calculate the average marks for each student and display their names along with their average marks.
#
# 7. Calculate and display the overall class average.
#
# 8. Implement a loop so that the user can re-enter data if an exception occurs or continue calculating for another class.
#
# 9. Include a graceful exit message when the user decides to stop.
#
# Custom(User Defined) Exceptions: Define two custom exception classes:
#
# `NegativeValueError: This exception should be raised when any of the subject marks are negative.
#
# `InvalidNumber Error: This exception should be raised when the user enters an invalid number for the total number of students (e.g., a negative number)

# %%
    
    try:
        def allstud_avg(total_students):
            
            total_students = int(input("enter the total number of students : "))
            if total_students<=0:
                 raise InvalidNumberError("please Enter a valid number")
            
            student_name1 = input("enter the name1 : ")
            maths_name1_score = int(input("enter the maths score1 : "))
            science_name1_score = int(input("enter the science score1 : "))
            social_name1_score = int(input("enter the social score1 : "))
            
            student_name1_score = dict(Maths ={maths_name1_score}  , science = {science_name1_score}  , social = {social_name1_score} )
            
            student_name1_avg = ((maths_name1_score+science_name1_score+social_name1_score)/3)
            print(student_name1_avg)
            
            student_name2 = input("enter the name2 : ")
            maths_name2_score = int(input("enter the maths score2 : "))
            science_name2_score = int(input("enter the science score2 : "))
            social_name2_score = int(input("enter the social score2 : "))
            
            student_name2_score = dict(Maths ={maths_name2_score}  , science = {science_name2_score}  , social = {social_name2_score} )
            
            student_name2_avg = ((maths_name2_score+science_name2_score+social_name2_score)/3)
            print(student_name2_avg)
            
            student_name3 = input("enter the name3 : ")
            maths_name3_score = int(input("enter the maths score3 : "))
            science_name3_score = int(input("enter the science score3 : "))
            social_name3_score = int(input("enter the social score3 : "))
            
            student_name3_score = dict(Maths ={maths_name3_score}  , science = {science_name3_score}  , social = {social_name3_score} )
            
            student_name3_avg = ((maths_name3_score+science_name3_score+social_name3_score)/3)
            print(student_name3_avg)
            
            all_avg=((student_name1_avg+student_name2_avg+student_name3_avg)/3)
            print(f"total class average : {all_avg}")
                     
        allstud_avg(total_students)
    except ValueError:
        print("please enter a numeric values")
    except ZeroDivisionError:
        print("please provide a valid details")
    except NegativeValueError:
        print("please enter a positive numbers only")
    finally:
        print("Thank you! have a nice day")
# Out:
# enter the total number of students : 3
# enter the name1 : sowji
# enter the maths score1 : 56
# enter the science score1 : 67
# enter the social score1 : 78
# 67.0
# enter the name2 : sruthi
# enter the maths score2 : 77
# enter the science score2 : 88
# enter the social score2 : 99
# 88.0
# enter the name3 : swathi
# enter the maths score3 : 88
# enter the science score3 : 99
# enter the social score3 : 97
# 94.66666666666667
# total class average : 83.22222222222223
# Thank you! have a nice day
