# %% [markdown]
# # Data visualization

# %% [markdown]
# pandas ,matplotlib --almst same visualistn
#
# seaborn - advanced visualisation

# %% [markdown]
# **what are the insights to find using data visualization?**
#
# 1. B--> breakdown/divide the data(boxplot,pie chart)
# 2. C-->compare the data(line,stacked bar)
# 3. D--> distribution of the data(histogram,density plot,QQplot)
# 4. R--->relationship
# 5. T---->Trends(predicting the future sales)

# %% [markdown]
# **Types of Data Visualization**

# %% [markdown]
# 1. univariate Analysis--single column
# 2. Bi variate Analysis--2 columns
# 3. Multivariate Analysis--more than 2

# %% [markdown]
# ## univariate Analysis

# %% [markdown]
# 1. it can be number or categorical
# 2. if the data contains numerical/numbers--> we need to use HBD plot(h-histogram,b-boxplot,d-density plot)
# 3. if the data contains categorical variates--> we use CBP plot(c-countplot,barplot,piechart)

# %% [markdown]
# countplot is from seaborn, countplot and barplot are same, barplot is from pandas and matplotlib

# %% [markdown]
# Numerical:
#
#     Histogram -- To find the 'Distribution'(fre/count vs columns)
#     boxplot---breakdown, to check the outliers
#     density--To find the distribution(probabilty density vs columns)

# %% [markdown]
# # Anatomy of plot

# %% [markdown]
# Parameters of the plot
# 1. x-axis-->x labels , y-axis-->y labels
# 2. dots on x and y axis is called x ticks and y ticks(value representation of repsective columns)
# 3. legends --indicating colours of each bar
# 4. binsize
# 5. color
# 6. Title of the plot

# %% [markdown]
# Title : Car Price Analysis
#
# Problem statement : Analysing the price of the car based upon some input features/columns
#
# features(brand, no of doors,capacity, fueltype, cylinder,mpq

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing the Dataset

# %%
df = pd.read_csv(r"C:\Users\anaji\Sowjanya\car_df_EDA.csv")
df.head()  # first 5 rows of columns
# Out:
#    Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0             0           1  alfa-romero       gas        std          two
# 1             1           2  alfa-romero       gas        std          two
# 2             2           3  alfa-romero       gas        std          two
# 3             3           4         audi       gas        std         four
# 4             4           5         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 0  convertible          rwd           front        88.6  ...         dohc
# 1  convertible          rwd           front        88.6  ...         dohc
# 2    hatchback          rwd           front        94.5  ...         ohcv
# 3        sedan          fwd           front        99.8  ...          ohc
# 4        sedan          4wd           front        99.4  ...          ohc
#
# ...

# %%
file = open (r"C:\Users\anaji\Sowjanya\data_description.txt")

# %%
print(file.read())
# Out:
# 1. `Unnamed: 0.1`: An unnamed or index column, possibly used for row identification.
# 2. `Unnamed: 0`: Another unnamed or index column, which may also serve for row identification.
# 3. `make`: The brand or manufacturer of the vehicle.
# 4. `fuel_type`: The type of fuel the vehicle uses (e.g., gasoline, diesel, etc.).
# 5. `aspiration`: Indicates whether the engine has a turbocharger or is naturally aspirated.
# 6. `num_of_doors`: The number of doors on the vehicle (e.g., two doors, four doors).
# 7. `body_style`: Describes the body style of the vehicle (e.g., sedan, coupe, hatchback).
# 8. `drive_wheels`: Specifies the type of drive wheels (e.g., front-wheel drive, rear-wheel drive, all-wheel drive).
# 9. `engine_location`: Indicates where the engine is located in the vehicle (e.g., front, rear).
# 10. `wheel_base`: The distance between the front and rear axles of the vehicle.
# 11. `length`: The length of the vehicle.
# 12. `width`: The width of the vehicle.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       208 non-null    int64
#  1   Unnamed: 0         208 non-null    int64
#  2   make               208 non-null    object
#  3   fuel_type          208 non-null    object
#  4   aspiration         208 non-null    object
#  5   num_of_doors       208 non-null    object
#  6   body_style         208 non-null    object
#  7   drive_wheels       208 non-null    object
#  8   engine_location    208 non-null    object
#  9   wheel_base         206 non-null    float64
#  10  length             208 non-null    float64
#  11  width              208 non-null    float64
#  12  height             208 non-null    float64
#  13  curb_weight        208 non-null    int64
#  14  engine_type        207 non-null    object
#  15  num_of_cylinders   208 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0  wheel_base      length       width  \
# count    208.000000  208.000000  206.000000  208.000000  208.000000
# mean     103.456731  104.456731   98.919903  174.262019   65.950962
# std       60.115573   60.115573    6.121266   12.373790    2.159419
# min        0.000000    1.000000   86.600000  141.100000   60.300000
# 25%       51.750000   52.750000   94.500000  166.675000   64.100000
# 50%      103.500000  104.500000   97.000000  173.200000   65.500000
# 75%      155.250000  156.250000  102.400000  183.775000   66.900000
# max      204.000000  205.000000  120.900000  208.100000   72.300000
#
#            height  curb_weight  engine_size  compression_ratio    city_mpg  \
# count  208.000000   208.000000   206.000000         208.000000  208.000000
# mean    53.750481  2563.375000   127.543689          10.194808   25.158654
# std      2.435010   521.034018    41.599197           4.044135    6.528187
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. what is the maximum price of audi car?

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# # to check duplicate values

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.duplicated()]
# Out:
#      Unnamed: 0.1  Unnamed: 0   make fuel_type aspiration num_of_doors  \
# 205           202         203  volvo       gas        std         four
# 206           203         204  volvo    diesel      turbo         four
# 207           204         205  volvo       gas      turbo         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 205      sedan          rwd           front       109.1  ...         ohcv
# 206      sedan          rwd           front       109.1  ...          ohc
# 207      sedan          rwd           front       109.1  ...          ohc
#
#      num_of_cylinders  engine_size  fuel_system compression_ratio horsepower  \
# 205               six        173.0         mpfi               8.8        134
# 206               six        145.0          idi              23.0        106
# 207              four        141.0         mpfi               9.5        114
#
#      peak_rpm city_mpg  highway_mpg  price
# ...

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # structural errors

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis =1 ,inplace = True)

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# to find structural erros:
#     if data type is categorical-- use unique method
#     if data type is numerical ---

# %%
df['make'].dtype,df['make'].unique()
# Out:
# (dtype('O'),
#  array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#         'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#         'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#         'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object))

# %%
df['fuel_type'].dtype,df['fuel_type'].unique()
# Out:
# (dtype('O'), array(['gas', 'diesel'], dtype=object))

# %%
df['aspiration'].dtype,df['aspiration'].unique()
# Out:
# (dtype('O'), array(['std', 'turbo'], dtype=object))

# %%
df['num_of_doors'].dtype
# Out:
# dtype('O')

# %%
df['num_of_doors'].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
def door(n):
    if n == 'two':
        return 2
    elif n == 'four':
        return 4
    else:
        return np.nan

# %%
df['num_of_doors']= df['num_of_doors'].apply(door)

# %%
df['num_of_doors'].unique()
# Out:
# array([ 2.,  4., nan])

# %%
df['body_style'].dtype
# Out:
# dtype('O')

# %%
df['body_style'].unique()   #to check structural errors and datatype for categoriacl we ise unique
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['length'].unique()
# Out:
# array([168.8, 171.2, 176.6, 177.3, 192.7, 178.2, 176.8, 189. , 193.8,
#        197. , 141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. ,
#        163.4, 157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7,
#        159.1, 166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3,
#        208.1, 199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4,
#        173.4, 181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 175.7,
#        181.5, 186.6, 156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7,
#        166.3, 168.7, 176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7,
#        180.2, 183.1, 188.8])

# %%
df['width'].unique()
# Out:
# array([64.1, 65.5, 66.2, 66.4, 66.3, 71.4, 67.9, 64.8, 66.9, 70.9, 60.3,
#        63.6, 63.8, 64.6, 63.9, 64. , 65.2, 62.5, 66. , 61.8, 69.6, 70.6,
#        64.2, 65.7, 66.5, 66.1, 70.3, 71.7, 70.5, 72. , 68. , 64.4, 65.4,
#        68.4, 68.3, 65. , 72.3, 66.6, 63.4, 65.6, 67.7, 67.2, 68.9, 68.8])

# %%
df['wheel_base'].unique()
# Out:
# array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2,   nan, 103.5,
#        110. ,  88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. ,
#        113. , 102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6,
#        120.9, 112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,
#         99.2, 107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,
#         97. ,  96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1])

# %%
df['height'].unique()
# Out:
# array([48.8, 52.4, 54.3, 53.1, 55.7, 55.9, 52. , 53.7, 56.3, 53.2, 50.8,
#        50.6, 59.8, 50.2, 52.6, 54.5, 58.3, 53.3, 54.1, 51. , 53.5, 51.4,
#        52.8, 47.8, 49.6, 55.5, 54.4, 56.5, 58.7, 54.9, 56.7, 55.4, 54.8,
#        49.4, 51.6, 54.7, 55.1, 56.1, 49.7, 56. , 50.5, 55.2, 52.5, 53. ,
#        59.1, 53.9, 55.6, 56.2, 57.5])

# %%
df['curb_weight'].unique()
# Out:
# array([2548, 2823, 2337, 2824, 2507, 2844, 2954, 3086, 3053, 2395, 2710,
#        2765, 3055, 3230, 3380, 3505, 1488, 1874, 1909, 1876, 2128, 1967,
#        1989, 2191, 2535, 2811, 1713, 1819, 1837, 1940, 1956, 2010, 2024,
#        2236, 2289, 2304, 2372, 2465, 2293, 2734, 4066, 3950, 1890, 1900,
#        1905, 1945, 1950, 2380, 2385, 2500, 2410, 2443, 2425, 2670, 2700,
#        3515, 3750, 3495, 3770, 3740, 3685, 3900, 3715, 2910, 1918, 1944,
#        2004, 2145, 2370, 2328, 2833, 2921, 2926, 2365, 2405, 2403, 1889,
#        2017, 1938, 1951, 2028, 1971, 2037, 2008, 2324, 2302, 3095, 3296,
#        3060, 3071, 3139, 3020, 3197, 3430, 3075, 3252, 3285, 3485, 3130,
#        2818, 2778, 2756, 2800, 3366, 2579, 2460, 2658, 2695, 2707, 2758,
#        2808, 2847, 2050, 2120, 2240, 2190, 2340, 2510, 2290, 2455, 2420,
#        2650, 1985, 2040, 2015, 2280, 3110, 2081, 2109, 2275, 2094, 2122,
#        2140, 2169, 2204, 2265, 2300, 2540, 2536, 2551, 2679, 2714, 2975,
# ...

# %%
df['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', nan, 'ohcf', 'dohcv'],
#       dtype=object)

# %%
df['num_of_cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
def dyl(n):
    if n == 'two':
        return 2
    elif n == 'three':
        return 3
    elif n == 'three':
        return 3
        return 2
    elif n == 'five':
        return 5
        return 2
    elif n == 'six':
        return 6
        return 2
    elif n == 'eight':
        return 8
        return 2
    else:
        return 12

# %%
df['num_of_cylinders']=df['num_of_cylinders'].apply(dyl)

# %%
df['num_of_cylinders'].unique()
# Out:
# array([12,  6,  5,  3,  2,  8], dtype=int64)

# %%
df['engine_size'].unique()
# Out:
# array([130., 152., 109., 136., 131., 108., 164., 209.,  61.,  90.,  98.,
#        122., 156.,  92.,  79., 110.,  nan, 111., 119., 258., 326.,  91.,
#         70.,  80., 140., 134., 183., 234., 308., 304.,  97., 103., 120.,
#        181., 151., 194., 203., 132., 121., 146., 171., 161., 141., 173.,
#        145.])

# %%
df['fuel_system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df['compression_ratio'].unique()
# Out:
# array([ 9.  , 10.  ,  8.  ,  8.5 ,  8.3 ,  7.  ,  8.8 ,  9.5 ,  9.6 ,
#         9.41,  9.4 ,  7.6 ,  9.2 , 10.1 ,  9.1 ,  8.1 , 11.5 ,  8.6 ,
#        22.7 , 22.  , 21.5 ,  7.5 , 21.9 ,  7.8 ,  8.4 , 21.  ,  8.7 ,
#         9.31,  9.3 ,  7.7 , 22.5 , 23.  ])

# %%
df['horsepower'].dtype
# Out:
# dtype('O')

# %%
df['horsepower'] = df['horsepower'].astype(str).replace('?', np.nan)  #first method

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', nan, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['horsepower'].str.isnumeric().value_counts ()
# Out:
# True     206
# False      2
# Name: horsepower, dtype: int64

# %%
df[~df['horsepower'].str.isnumeric()]                                                     #second method
# Out:
#         make fuel_type aspiration num_of_doors body_style drive_wheels  \
# 130  renault       gas        std         four      wagon          fwd
# 131  renault       gas        std          two  hatchback          fwd
#
#     engine_location  wheel_base  length  width  ...  engine_type  \
# 130           front        96.1   181.5   66.5  ...          ohc
# 131           front        96.1   176.8   66.6  ...          ohc
#
#      num_of_cylinders engine_size fuel_system  compression_ratio horsepower  \
# 130              four       132.0        mpfi                8.7          ?
# 131              four       132.0        mpfi                8.7          ?
#
#      peak_rpm city_mpg highway_mpg  price
# 130         ?       23          31   9295
# 131         ?       23          31   9895
#
# [2 rows x 22 columns]

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', nan, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['peak_rpm'].dtype
# Out:
# dtype('O')

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['peak_rpm']=df['peak_rpm'].replace('?',np.nan)

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['city_mpg'].dtype,df['city_mpg'].unique()
# Out:
# (dtype('int64'),
#  array([21, 19, 24, 18, 17, 16, 23, 20, 15, 47, 38, 37, 31, 49, 30, 27, 25,
#         13, 26, 36, 22, 14, 45, 28, 32, 35, 34, 29, 33], dtype=int64))

# %%
df['highway_mpg'].dtype,df['highway_mpg'].unique()
# Out:
# (dtype('int64'),
#  array([27, 26, 30, 22, 25, 20, 29, 28, 53, 43, 41, 38, 24, 54, 42, 34, 33,
#         31, 19, 17, 23, 32, 39, 18, 16, 37, 50, 36, 47, 46], dtype=int64))

# %%
df['price'].dtype,df['price'].unique()
# Out:
# (dtype('O'),
#  array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#         '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#         '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#         '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#         '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#         '12945', '10345', '6785', '11048', nan, '35550', '36000', '5195',
#         '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#         '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#         '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#         '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#         '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#         '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#         '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['price']=df['price'].replace('?',np.nan)

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', nan, '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %% [markdown]
# # Missing values

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                7
# dtype: int64

# %%
df['num_of_doors'].fillna(df['num_of_doors'].mode()[0],inplace=True)
df['wheel_base'].fillna(df['wheel_base'].mean(),inplace=True)
df['engine_type'].fillna(df['engine_type'].mode()[0],inplace=True)
df['engine_size'].fillna(df['engine_size'].median(),inplace=True)
df['horsepower'].fillna(df['horsepower'].median(),inplace=True)
df['peak_rpm'].fillna(df['peak_rpm'].median(),inplace=True)
df['price'].fillna(df['price'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %% [markdown]
# # Type casting

# %%
df["price"] = df["price"].astype("int64")
df["peak_rpm"] = df["peak_rpm"].astype("int64")
df["horsepower"] = df["horsepower"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               205 non-null    object
#  1   fuel_type          205 non-null    object
#  2   aspiration         205 non-null    object
#  3   num_of_doors       205 non-null    float64
#  4   body_style         205 non-null    object
#  5   drive_wheels       205 non-null    object
#  6   engine_location    205 non-null    object
#  7   wheel_base         205 non-null    float64
#  8   length             205 non-null    float64
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  curb_weight        205 non-null    int64
#  12  engine_type        205 non-null    object
#  13  num_of_cylinders   205 non-null    int64
#  14  engine_size        205 non-null    float64
#  15  fuel_system        205 non-null    object
# ...

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# # Histograms

# %% [markdown]
# # num_of_cylinders

# %%
plt.style.use('ggplot')

# %%
df['num_of_cylinders'].plot(kind='hist',
                           xlabel='No of Cylinders',
                           title='Histogram of No of cylinders',
                           color='blue',
                           figsize=(4,5))
# Out:
# <Axes: title={'center': 'Histogram of No of cylinders'}, ylabel='Frequency'>

# %% [markdown]
# # wheel base

# %%
plt.style.use('classic')

# %%
df['wheel_base'].plot(kind='hist',
                           xlabel='wheel base',
                           title='Histogram of wheel base',
                           color='green',
                           figsize=(4,5))
# Out:
# <Axes: title={'center': 'Histogram of wheel base'}, ylabel='Frequency'>

# %% [markdown]
# # curb_weight

# %%
plt.style.use('Solarize_Light2')

# %%
df['curb_weight'].plot(kind='hist',
                           xlabel='curb weight',
                           title='Histogram of curbweight',
                           color='black',
                           figsize=(4,3))
# Out:
# <Axes: title={'center': 'Histogram of curbweight'}, ylabel='Frequency'>

# %% [markdown]
# # horsepower

# %%
plt.style.use('fast')

# %%
df['horsepower'].plot(kind='hist',
                           xlabel='horsepower',
                           title='Histogram of horsepower',
                           color='green',
                           figsize=(4,3))
# Out:
# <Axes: title={'center': 'Histogram of horsepower'}, ylabel='Frequency'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
for i in df.columns:
    print(i)
    print(df[i].dtype)      #instead of checking the data type and structural erros for each one, we can use for loop
    print(df[i].unique())
# Out:
# make
# object
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# fuel_type
# object
# ['gas' 'diesel']
# aspiration
# object
# ['std' 'turbo']
# num_of_doors
# float64
# [2. 4.]
# body_style
# object
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drive_wheels
# object
# ['rwd' 'fwd' '4wd']
# engine_location
# object
# ['front' 'rear']
# wheel_base
# float64
# [ 88.6         94.5         99.8         99.4        105.8
#   99.5        101.2         98.76945813 103.5        110.
#   88.4         93.7        103.3         95.9         86.6
#   96.5         94.3         96.         113.         102.
#   93.1         95.3         98.8        104.9        106.7
#  115.6         96.6        120.9        112.         102.7
#   93.          96.3         95.1         97.2        100.4
# ...

# %%
plt.style.use('classic')

# %%
df['horsepower'].plot(kind='hist',
                           xlabel='horsepower',
                           title='Histogram of horsepower',
                           color='#42f5da',  #color picker through online
                           figsize=(4,3))
# Out:
# <Axes: title={'center': 'Histogram of horsepower'}, ylabel='Frequency'>

# %% [markdown]
# # Boxplot
#
# to get the outliers

# %%
df['price'].plot(kind='box',
                figsize=(5,3))
# Out:
# <Axes: >

# %%
df['highway_mpg'].plot(kind = 'box',figsize=(5,3))
# Out:
# <Axes: >

# %%
It displays the minimum, first quartile (Q1), median, third quartile (Q3), and maximum of a dataset.

# %%
The interquartile range (IQR) is a measure of statistical dispersion, and it is the range between Q1 and Q3.

# %% [markdown]
# Minimum: 17
#
# Lower quartile Q1: 25
#
# Q2 median(q2):30
#
# Q3 : Upper quartile (0.75):37
#
# Maximum Value:47
#
# Outliers:above 47 or below 16

# %%
#bluedotted vertical line is called whisker

# %% [markdown]
# Negatively Skewed:
#
# The mean is typically less than the median, and the distribution is stretched towards lower values.
# In practical terms, this might mean that there are a few extremely low values pulling the mean down.
# For financial data, a negatively skewed distribution might suggest that there are more gains and fewer losses.
#
# Positively Skewed:
#
# The mean is usually greater than the median, and the distribution is stretched towards higher values.
# This could imply that there are a few extremely high values pulling the mean up.
# In financial data, a positively skewed distribution might indicate more losses and fewer gains.
#
# Outliers:
#
# Outliers can have a significant impact on summary statistics like the mean. A single extremely high or low value can distort the mean, making it less representative of the central tendency of the data.
# The median is less affected by outliers, as it is not influenced by extreme values to the same extent as the mean.

# %% [markdown]
# # understanding normal distribution based on box plot

# %%
df['length'].plot(kind='kde',color= 'purple',figsize=(5,3)) #bellshape and symmetrical representation through median-normal dist
# Out:
# <Axes: ylabel='Density'>

# %%
df['length'].plot(kind='box',color= 'purple',figsize=(5,3))  #Q2 is partially/almost in middle at 175 so normal distribution
                                                             #whisker length on both sides is equal
# Out:
# <Axes: >

# %% [markdown]
# The box represents the interquartile range (IQR), which is the range between Q1 and Q3.
# The line inside the box represents the median.

# %% [markdown]
# **we can use box plot for distribution**
# 1. need to have same whisker lengths
# 2. median or Q2 (50%) should be exactly half of the box

# %%
df['length'].mean(),df['length'].median()  #closed value, so its normla distribution(stastiical method)
# Out:
# (174.04926829268288, 173.2)

# %% [markdown]
# ### violin plot
# combination of box plot and density plot

# %% [markdown]
# # Categorical

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df['make'].plot(kind='bar') #it shows error as it doesn't give freq of the data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df['make'].plot(kind='bar')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# ...

# %%
df['make'].value_counts().plot(kind='bar',figsize=(5,3)) #it shows error as it doesn't give freq of the data
# Out:
# <Axes: >

# %%
# the basic difference of histogram and bar graph, there is gap between the bars

# %% [markdown]
# #conclusions from above graph:
# 1.In our data, toyota have 30 freq or the count of toyota is more.
# 2.mercuey num of cars are less

# %%
df['fuel_type'].value_counts().plot(kind='bar',figsize=(6,4),color = ['red','green'],grid=True,position=1)
# Out:
# <Axes: >

# %%
#there are more number of cars which use gas rather than diesel
#if give position 1, gas and diesel names will be at end of the bar(0-1),0.5 then middle

# %%
df['fuel_type'].value_counts().plot(kind='barh',figsize=(6,4),color = ['red','green'],grid=True,position=1,subplots= True)
# Out:
# array([<Axes: title={'center': 'fuel_type'}>], dtype=object)

# %% [markdown]
# # seaborn

# %%
sns.countplot(data=df,x='make',width=0.5,orient= 'h')
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %% [markdown]
# # pie chart

# %% [markdown]
# Prefer pie chart if it is less than or almost 8 features, more than that look messy

# %%
df['body_style'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='body_style'>

# %%
# we need to change valuecounts to percentages(dividing)

# %%
df['body_style'].value_counts()/len(df['body_style'])*100
# Out:
# sedan          46.829268
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: body_style, dtype: float64

# %%
(df['body_style'].value_counts()/len(df['body_style'])*100).plot(kind='pie',ylabel='percentage',figsize=(8,10),autopct='%1.1f',legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# legend is a feature used in various plotting functions to provide additional information about the elements(sedan, wagon etc) in a plot

# %%
(df['engine_type'].value_counts()/len(df['engine_type'])*100).plot(kind='pie',ylabel='percentage',figsize=(10,9),autopct='%1.1f',legend=True)
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# # Bi variate analysis

# %% [markdown]
# Bivariate analysis is a kind of statistical analysis in which two variables are observed against each other
#
# 1.Categorical & Categorical
#
# 2.Cross tab, Count plot, Stacked/Group Bar chart
#
# Categorical & Numerical
#
# 3.Bar chart, Group By, Pivot, Line chart
#
# Numerical & Numerical
#
# Correlation, Scatter plot

# %% [markdown]
# #cross tab always gives frequency

# %% [markdown]
# # Categorical & Categorical

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
pd.crosstab(df['make'],df['fuel_type']) #gives count or frequency or num of cars
# Out:
# fuel_type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    7
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    4
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    5
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %%
pd.crosstab(df['fuel_type'],df['body_style'])
# Out:
# body_style  convertible  hardtop  hatchback  sedan  wagon
# fuel_type
# diesel                0        1          1     15      3
# gas                   6        7         69     81     22

# %%
pd.crosstab(df['aspiration'],df['drive_wheels'])
# Out:
# drive_wheels  4wd  fwd  rwd
# aspiration
# std             6  104   58
# turbo           3   16   18

# %%
sns.countplot(data = df,x  = 'body_style',hue = 'fuel_type')
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
import matplotlib.pyplot as plt

#data
groups=['G1','G2', 'G3', 'G4', 'G5']
male = [12,19,14,27,16]
female = [21, 30, 15, 17, 20]

fig, ax = plt.subplots()

#stacked bar chart
ax.bar(groups, male)
ax.bar(groups,female,bottom=male)

#plt.show()
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# if we want to deal with line chat,1 value should be numerical,value2 should be time or date(categorical)and that should be represented as xaxis

# %% [markdown]
# # Categorical & Numerical
#
#  Group By, Pivot, Line chart.

# %%
df.groupby(by ='engine_type' )['price'].min()
# Out:
# engine_type
# dohc      9298
# dohcv    10221
# l         5151
# ohc       5195
# ohcf      5118
# ohcv     13499
# rotor    10945
# Name: price, dtype: int64

# %%
df['price'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df['price'].head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %% [markdown]
# # Numerical & Numerical
# Scatter plot: always finds the relationship between 2 numerical columns

# %%
df.plot('wheel_base','length',kind = 'scatter')
# Out:
# <Axes: xlabel='wheel_base', ylabel='length'>

# %% [markdown]
# direction always gives positive or negative, directly proportional so positive
# strength : pearson co reltn co efficient val

# %%
df.plot('length','city_mpg',kind = 'scatter')
# Out:
# <Axes: xlabel='length', ylabel='city_mpg'>

# %% [markdown]
# conclusion : negative direction and moderate strength, inversely proportion

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434134  0.385675  0.197735  0.540286
# wheel_base             0.434134    1.000000  0.870403  0.793806  0.585280
# length                 0.385675    0.870403  1.000000  0.841118  0.491029
# width                  0.197735    0.793806  0.841118  1.000000  0.279210
# height                 0.540286    0.585280  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.773262  0.877728  0.867032  0.295572
# num_of_cylinders       0.078996   -0.241637 -0.316492 -0.420732  0.066886
# engine_size            0.017968    0.565307  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250218  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.350007  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.361671 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467094 -0.670909 -0.642704 -0.048640
# ...

# %%
df.plot('num_of_doors','price',kind='scatter')
# Out:
# C:\Users\anaji\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='num_of_doors', ylabel='price'>

# %% [markdown]
# here we cannot find any relation, the strength is weak

# %% [markdown]
# scatter plot is used to find the corelation btween numerical columns but its subjective and strength cannot be specified

# %% [markdown]
# # Multivariate analysis

# %%
df.corr()
# Out:
# C:\Users\anaji\AppData\Local\Temp\ipykernel_13868\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434134  0.385675  0.197735  0.540286
# wheel_base             0.434134    1.000000  0.870403  0.793806  0.585280
# length                 0.385675    0.870403  1.000000  0.841118  0.491029
# width                  0.197735    0.793806  0.841118  1.000000  0.279210
# height                 0.540286    0.585280  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.773262  0.877728  0.867032  0.295572
# num_of_cylinders       0.078996   -0.241637 -0.316492 -0.420732  0.066886
# engine_size            0.017968    0.565307  0.682920  0.733872  0.067997
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434134  0.385675  0.197735  0.540286
# wheel_base             0.434134    1.000000  0.870403  0.793806  0.585280
# length                 0.385675    0.870403  1.000000  0.841118  0.491029
# width                  0.197735    0.793806  0.841118  1.000000  0.279210
# height                 0.540286    0.585280  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.773262  0.877728  0.867032  0.295572
# num_of_cylinders       0.078996   -0.241637 -0.316492 -0.420732  0.066886
# engine_size            0.017968    0.565307  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250218  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.350007  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.361671 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467094 -0.670909 -0.642704 -0.048640
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot  =True) #annot:annotation
# Out:
# <Axes: >

# %% [markdown]
# **pairplot**

# %%
sns.pairplot(df)

# %%
#combination of histogram and scatter is above

# %% [markdown]
# # sea born

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
sns.boxplot(df['city_mpg'])
# Out:
# <Axes: >

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\anaji\AppData\Local\Temp\ipykernel_13868\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.catplot(df['fuel_type'])

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.jointplot(df['price'])

# %%
sns.lineplot(df['price'])
# Out:
# <Axes: ylabel='price'>
