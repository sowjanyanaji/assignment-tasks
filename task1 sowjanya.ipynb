# %% [markdown]
# ### Use different identifiers and assign the below values

# %% [markdown]
# Check the valid Identifiers and invalid identifers using Python
# Run all the identifiers and seprate valid and Invalid Identifiers?
#
# **Why Python treating them as invalid Identifers.Explain?**
#
# my_variable = 25
#
# **valid**
#
# counter = 40.7
#
# **valid**
#
# _total = "Hello"
#
# **valid**
#
# 123abc = 34
#
# **invalid**
#
# Note : We cannot give name starting with numbers
#
# my variable =6.7
#
# **invalid**
#
# Note : we cannot give space in between to the variable name
#
# @count = "hi"
#
# **invalid**
#
# Note : identifiers doesn't contain special characters except underscore
#
# for = "True"
#
# **invalid**
#
# Note : we shouldn't use key words as an identifier
#
# Name123 = 136
#
# **valid**
#
# myFunction = True
#
# **valid**
#
# _data = False
#
# **valid**
#
# if_condition? = "Innomatics"
#
# **invalid**
#
# Note : cannot use keywords
#
# class = "Hyderabad"
#
# **invalid**
#
# Note : class is a keyword
#
# **Use different identifiers and assign the below values**
#
# 10
#
# integer = 10
#
#
#
#
# -5
#
# Neg_= -5
#
#
#
#
#
# 3.14159
#
# pie = 3.14159
#
#
#
#
# -0.12345
#
# sowji= -0.12345
#
#
#
#
# 1000
#
# a = 1000
#
#
#
#
# "Hello, World!"
#
# Greetings2theworldwar1= "Hello, World!"
#
#
#
# "Python"
#
# string = "Python"
#
#
#
# "I am learning"
#
# Data_science_concept1= "I am learning"
#
#
#
# "Text type"
#
# message = "Text type"
#
#
#
# "String"
#
# Datatype = "String"
#
#
#
# True
#
# Sowjanya =True
#
#
#
# False
#
# Srilatha = False
#
#
#
#
#
# True
#
# Sowjanya_1 = True
#
#
#
#
# False
#
# _Srilatha = False
#
#
#
#
# True
#
# Sowjanya_2 = True
